# %% [markdown]
# <a href="https://colab.research.google.com/github/mmaguero/diploma_fpuna_nlp_ia/blob/master/2025/rag_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Building a Simple Chatbot with LangGraph and Chainlit:
# ## A Step-by-Step Tutorial

# %% [markdown]
# ## Prerequisites

# %%
# RAG Chatbot
# !pip install langgraph langchain-openai chainlit python-dotenv
# Out:
# Requirement already satisfied: langgraph in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting chainlit
#   Downloading chainlit-2.9.2-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (1.2.1)
# Requirement already satisfied: langchain-core>=0.1 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.0.7)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in /usr/local/lib/python3.12/dist-packages (from langgraph) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.3.0,>=0.2.2 in /usr/local/lib/python3.12/dist-packages (from langgraph) (0.2.9)
# Requirement already satisfied: pydantic>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langgraph) (2.11.10)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph) (3.6.0)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-1.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: openai<3.0.0,>=1.109.1 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (2.8.1)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai) (0.12.0)
# Requirement already satisfied: aiofiles<25.0.0,>=23.1.0 in /usr/local/lib/python3.12/dist-packages (from chainlit) (24.1.0)
# Collecting asyncer<0.1.0,>=0.0.8 (from chainlit)
#   Downloading asyncer-0.0.10-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.3 in /usr/local/lib/python3.12/dist-packages (from chainlit) (8.3.1)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from chainlit)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: fastapi>=0.116.1 in /usr/local/lib/python3.12/dist-packages (from chainlit) (0.118.3)
# Collecting filetype<2.0.0,>=1.2.0 (from chainlit)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: httpx>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from chainlit) (0.28.1)
# Collecting lazify<0.5.0,>=0.4.0 (from chainlit)
#   Downloading Lazify-0.4.0-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting literalai==0.1.201 (from chainlit)
#   Downloading literalai-0.1.201.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: mcp<2.0.0,>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from chainlit) (1.22.0)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from chainlit) (1.6.0)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.12/dist-packages (from chainlit) (25.0)
# Requirement already satisfied: pydantic-settings>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from chainlit) (2.12.0)
# Requirement already satisfied: pyjwt<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from chainlit) (2.10.1)
# Requirement already satisfied: python-multipart<1.0.0,>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from chainlit) (0.0.20)
# Collecting python-socketio<6.0.0,>=5.11.0 (from chainlit)
#   Downloading python_socketio-5.15.0-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: starlette>=0.47.2 in /usr/local/lib/python3.12/dist-packages (from chainlit) (0.48.0)
# Collecting syncer<3.0.0,>=2.0.3 (from chainlit)
#   Downloading syncer-2.0.3.tar.gz (11 kB)
#   Preparing metadata (setup.py) ... done
# Collecting tomli<3.0.0,>=2.0.1 (from chainlit)
#   Downloading tomli-2.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: uvicorn>=0.35.0 in /usr/local/lib/python3.12/dist-packages (from chainlit) (0.38.0)
# Collecting watchfiles<1.0.0,>=0.20.0 (from chainlit)
#   Downloading watchfiles-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Collecting chevron>=0.14.0 (from literalai==0.1.201->chainlit)
#   Downloading chevron-0.14.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting traceloop-sdk>=0.33.12 (from literalai==0.1.201->chainlit)
#   Downloading traceloop_sdk-0.49.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: anyio<5.0,>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from asyncer<0.1.0,>=0.0.8->chainlit) (4.11.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->chainlit)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->chainlit)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.116.1->chainlit) (4.15.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->chainlit) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->chainlit) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.23.0->chainlit) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.23.0->chainlit) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (0.4.45)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core>=0.1->langgraph) (9.1.2)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph) (1.12.0)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.4)
# Requirement already satisfied: httpx-sse>=0.4 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.11.0->chainlit) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.11.0->chainlit) (4.25.1)
# Requirement already satisfied: sse-starlette>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.11.0->chainlit) (3.0.3)
# Requirement already satisfied: typing-inspection>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from mcp<2.0.0,>=1.11.0->chainlit) (0.4.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<3.0.0,>=1.109.1->langchain-openai) (4.67.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.7.4->langgraph) (2.33.2)
# Collecting bidict>=0.21.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading bidict-0.23.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting python-engineio>=4.11.0 (from python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading python_engineio-4.12.3-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.4)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->chainlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->chainlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->chainlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.20.0->mcp<2.0.0,>=1.11.0->chainlit) (0.29.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: cryptography>=3.4.0 in /usr/local/lib/python3.12/dist-packages (from pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->chainlit) (43.0.3)
# Collecting simple-websocket>=0.10.0 (from python-engineio>=4.11.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading simple_websocket-1.1.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.5.0)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.11 in /usr/local/lib/python3.12/dist-packages (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (3.13.2)
# Collecting colorama<0.5.0,>=0.4.6 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting cuid<0.5,>=0.4 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading cuid-0.4.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deprecated<2.0.0,>=1.2.14 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.1.5 in /usr/local/lib/python3.12/dist-packages (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (3.1.6)
# Collecting opentelemetry-api<2.0.0,>=1.38.0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_api-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.38.0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-exporter-otlp-proto-http<2.0.0,>=1.38.0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_http-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-agno==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_agno-0.49.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-instrumentation-alephalpha==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_alephalpha-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-anthropic==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_anthropic-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-bedrock==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_bedrock-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-chromadb==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_chromadb-0.49.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-instrumentation-cohere==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_cohere-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-crewai==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_crewai-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-google-generativeai==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_google_generativeai-0.49.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-groq==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_groq-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-haystack==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_haystack-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-lancedb==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_lancedb-0.49.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-langchain==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_langchain-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-llamaindex==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_llamaindex-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-logging>=0.59b0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_logging-0.59b0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-instrumentation-marqo==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_marqo-0.49.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-mcp==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_mcp-0.49.2-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation-milvus==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_milvus-0.49.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-mistralai==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_mistralai-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-ollama==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_ollama-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-openai==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_openai-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-openai-agents==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_openai_agents-0.49.2-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-pinecone==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_pinecone-0.49.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-instrumentation-qdrant==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_qdrant-0.49.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-instrumentation-redis>=0.59b0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_redis-0.59b0-py3-none-any.whl.metadata (2.0 kB)
# Collecting opentelemetry-instrumentation-replicate==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_replicate-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-requests>=0.59b0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_requests-0.59b0-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-instrumentation-sagemaker==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_sagemaker-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-sqlalchemy>=0.59b0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_sqlalchemy-0.59b0-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-threading>=0.59b0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_threading-0.59b0-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation-together==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_together-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-transformers==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_transformers-0.49.2-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-instrumentation-urllib3>=0.59b0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_urllib3-0.59b0-py3-none-any.whl.metadata (4.2 kB)
# Collecting opentelemetry-instrumentation-vertexai==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_vertexai-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-instrumentation-watsonx==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_watsonx-0.49.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting opentelemetry-instrumentation-weaviate==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_weaviate-0.49.2-py3-none-any.whl.metadata (1.7 kB)
# Collecting opentelemetry-instrumentation-writer==0.49.2 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation_writer-0.49.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk<2.0.0,>=1.38.0 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-semantic-conventions-ai<0.5.0,>=0.4.13 (from traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl.metadata (1.1 kB)
# Collecting opentelemetry-instrumentation>=0.59b0 (from opentelemetry-instrumentation-agno==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_instrumentation-0.59b0-py3-none-any.whl.metadata (7.1 kB)
# Collecting opentelemetry-semantic-conventions>=0.59b0 (from opentelemetry-instrumentation-agno==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting anthropic>=0.17.0 (from opentelemetry-instrumentation-bedrock==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading anthropic-0.75.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: tokenizers>=0.13.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-instrumentation-bedrock==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (0.22.1)
# Collecting inflection<0.6.0,>=0.5.1 (from opentelemetry-instrumentation-llamaindex==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading inflection-0.5.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->chainlit)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.11->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.11->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.11->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.11->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.11->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.11.11->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (1.22.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.12/dist-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->chainlit) (2.0.0)
# Requirement already satisfied: wrapt<3,>=1.10 in /usr/local/lib/python3.12/dist-packages (from deprecated<2.0.0,>=1.2.14->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0.0,>=3.1.5->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (3.0.3)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<2.0.0,>=1.38.0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (8.7.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.38.0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (1.72.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.38.0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (1.76.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.38.0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl.metadata (1.8 kB)
# Collecting opentelemetry-proto==1.38.0 (from opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.38.0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_proto-1.38.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: protobuf<7.0,>=5.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-proto==1.38.0->opentelemetry-exporter-otlp-proto-grpc<2.0.0,>=1.38.0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (5.29.5)
# Collecting wrapt<3,>=1.10 (from deprecated<2.0.0,>=1.2.14->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (6.4 kB)
# Collecting opentelemetry-util-http==0.59b0 (from opentelemetry-instrumentation-requests>=0.59b0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit)
#   Downloading opentelemetry_util_http-0.59b0-py3-none-any.whl.metadata (2.6 kB)
# Collecting wsproto (from simple-websocket>=0.10.0->python-engineio>=4.11.0->python-socketio<6.0.0,>=5.11.0->chainlit)
#   Downloading wsproto-1.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /usr/local/lib/python3.12/dist-packages (from anthropic>=0.17.0->opentelemetry-instrumentation-bedrock==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (0.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp<2.0.0,>=1.11.0->chainlit) (2.23)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.38.0->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (3.23.0)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers>=0.13.0->opentelemetry-instrumentation-bedrock==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->opentelemetry-instrumentation-bedrock==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->opentelemetry-instrumentation-bedrock==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.0->opentelemetry-instrumentation-bedrock==0.49.2->traceloop-sdk>=0.33.12->literalai==0.1.201->chainlit) (1.2.0)
# Downloading langchain_openai-1.1.0-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.3/84.3 kB 6.2 MB/s eta 0:00:00
# Downloading chainlit-2.9.2-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 88.2 MB/s eta 0:00:00
# Downloading asyncer-0.0.10-py3-none-any.whl (9.5 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading langchain_core-1.1.0-py3-none-any.whl (473 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 473.8/473.8 kB 27.7 MB/s eta 0:00:00
# Downloading Lazify-0.4.0-py2.py3-none-any.whl (3.1 kB)
# Downloading python_socketio-5.15.0-py3-none-any.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 6.0 MB/s eta 0:00:00
# Downloading tomli-2.3.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (250 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.1/250.1 kB 19.8 MB/s eta 0:00:00
# Downloading watchfiles-0.24.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (425 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.7/425.7 kB 28.7 MB/s eta 0:00:00
# Downloading bidict-0.23.1-py3-none-any.whl (32 kB)
# Downloading chevron-0.14.0-py3-none-any.whl (11 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 2.8 MB/s eta 0:00:00
# Downloading python_engineio-4.12.3-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 3.8 MB/s eta 0:00:00
# Downloading traceloop_sdk-0.49.2-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 3.3 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_agno-0.49.2-py3-none-any.whl (6.9 kB)
# Downloading opentelemetry_instrumentation_alephalpha-0.49.2-py3-none-any.whl (8.1 kB)
# Downloading opentelemetry_instrumentation_anthropic-0.49.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_instrumentation_bedrock-0.49.2-py3-none-any.whl (19 kB)
# Downloading opentelemetry_instrumentation_chromadb-0.49.2-py3-none-any.whl (6.3 kB)
# Downloading opentelemetry_instrumentation_cohere-0.49.2-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation_crewai-0.49.2-py3-none-any.whl (6.2 kB)
# Downloading opentelemetry_instrumentation_google_generativeai-0.49.2-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation_groq-0.49.2-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation_haystack-0.49.2-py3-none-any.whl (7.5 kB)
# Downloading opentelemetry_instrumentation_lancedb-0.49.2-py3-none-any.whl (4.8 kB)
# Downloading opentelemetry_instrumentation_langchain-0.49.2-py3-none-any.whl (18 kB)
# Downloading opentelemetry_instrumentation_llamaindex-0.49.2-py3-none-any.whl (21 kB)
# Downloading opentelemetry_instrumentation_marqo-0.49.2-py3-none-any.whl (5.1 kB)
# Downloading opentelemetry_instrumentation_mcp-0.49.2-py3-none-any.whl (10 kB)
# Downloading opentelemetry_instrumentation_milvus-0.49.2-py3-none-any.whl (7.2 kB)
# Downloading opentelemetry_instrumentation_mistralai-0.49.2-py3-none-any.whl (8.9 kB)
# Downloading opentelemetry_instrumentation_ollama-0.49.2-py3-none-any.whl (11 kB)
# Downloading opentelemetry_instrumentation_openai-0.49.2-py3-none-any.whl (36 kB)
# Downloading opentelemetry_instrumentation_openai_agents-0.49.2-py3-none-any.whl (9.8 kB)
# Downloading opentelemetry_instrumentation_pinecone-0.49.2-py3-none-any.whl (6.4 kB)
# Downloading opentelemetry_instrumentation_qdrant-0.49.2-py3-none-any.whl (6.3 kB)
# Downloading opentelemetry_instrumentation_replicate-0.49.2-py3-none-any.whl (8.2 kB)
# Downloading opentelemetry_instrumentation_sagemaker-0.49.2-py3-none-any.whl (9.8 kB)
# Downloading opentelemetry_instrumentation_together-0.49.2-py3-none-any.whl (8.7 kB)
# Downloading opentelemetry_instrumentation_transformers-0.49.2-py3-none-any.whl (8.3 kB)
# Downloading opentelemetry_instrumentation_vertexai-0.49.2-py3-none-any.whl (10 kB)
# Downloading opentelemetry_instrumentation_watsonx-0.49.2-py3-none-any.whl (10 kB)
# Downloading opentelemetry_instrumentation_weaviate-0.49.2-py3-none-any.whl (6.4 kB)
# Downloading opentelemetry_instrumentation_writer-0.49.2-py3-none-any.whl (11 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading opentelemetry_api-1.38.0-py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.9/65.9 kB 4.4 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.38.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.38.0-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.38.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 6.1 MB/s eta 0:00:00
# Downloading opentelemetry_exporter_otlp_proto_http-1.38.0-py3-none-any.whl (19 kB)
# Downloading opentelemetry_instrumentation_logging-0.59b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.59b0-py3-none-any.whl (33 kB)
# Downloading opentelemetry_semantic_conventions-0.59b0-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.0/208.0 kB 14.9 MB/s eta 0:00:00
# Downloading opentelemetry_instrumentation_redis-0.59b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_instrumentation_requests-0.59b0-py3-none-any.whl (12 kB)
# Downloading opentelemetry_util_http-0.59b0-py3-none-any.whl (7.6 kB)
# Downloading opentelemetry_instrumentation_sqlalchemy-0.59b0-py3-none-any.whl (14 kB)
# Downloading opentelemetry_instrumentation_threading-0.59b0-py3-none-any.whl (9.3 kB)
# Downloading opentelemetry_instrumentation_urllib3-0.59b0-py3-none-any.whl (13 kB)
# Downloading opentelemetry_sdk-1.38.0-py3-none-any.whl (132 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.3/132.3 kB 10.9 MB/s eta 0:00:00
# Downloading opentelemetry_semantic_conventions_ai-0.4.13-py3-none-any.whl (6.1 kB)
# Downloading simple_websocket-1.1.0-py3-none-any.whl (13 kB)
# Downloading anthropic-0.75.0-py3-none-any.whl (388 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.2/388.2 kB 29.6 MB/s eta 0:00:00
# Downloading inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Downloading wrapt-1.17.3-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 kB 7.3 MB/s eta 0:00:00
# Downloading wsproto-1.3.2-py3-none-any.whl (24 kB)
# Building wheels for collected packages: literalai, syncer, cuid
#   Building wheel for literalai (setup.py) ... done
#   Created wheel for literalai: filename=literalai-0.1.201-py3-none-any.whl size=89088 sha256=82fe7ddc390b8ca332162e8845c7679f1e75721243154a308844bbaac938a18d
#   Stored in directory: /root/.cache/pip/wheels/82/08/89/6cbb396706aec55a6dc2352136828887aa9c34effdbb7d971e
#   Building wheel for syncer (setup.py) ... done
#   Created wheel for syncer: filename=syncer-2.0.3-py2.py3-none-any.whl size=3437 sha256=648620e9f5bf832b9a69293a7e1ddd41286dff410a4580658e953902d42e973e
#   Stored in directory: /root/.cache/pip/wheels/9f/d9/17/203397abf217c535e6725b8d9e0cd99e8c5ccb24c0bcb51997
#   Building wheel for cuid (setup.py) ... done
#   Created wheel for cuid: filename=cuid-0.4-py2.py3-none-any.whl size=4713 sha256=f152a93652b477107621fc2f3d6f18fb03c53db73f423759c9a16881ba3d59c3
#   Stored in directory: /root/.cache/pip/wheels/c1/9e/b8/eacbcd00d06e506913e04e7574775b2ddcb8fc78658823a0ca
# Successfully built literalai syncer cuid
# Installing collected packages: syncer, lazify, filetype, cuid, chevron, wsproto, wrapt, tomli, opentelemetry-util-http, opentelemetry-semantic-conventions-ai, opentelemetry-proto, mypy-extensions, marshmallow, inflection, colorama, bidict, watchfiles, typing-inspect, simple-websocket, opentelemetry-exporter-otlp-proto-common, opentelemetry-api, deprecated, asyncer, python-engineio, opentelemetry-semantic-conventions, dataclasses-json, anthropic, python-socketio, opentelemetry-sdk, opentelemetry-instrumentation, langchain-core, opentelemetry-instrumentation-writer, opentelemetry-instrumentation-weaviate, opentelemetry-instrumentation-watsonx, opentelemetry-instrumentation-vertexai, opentelemetry-instrumentation-urllib3, opentelemetry-instrumentation-transformers, opentelemetry-instrumentation-together, opentelemetry-instrumentation-threading, opentelemetry-instrumentation-sqlalchemy, opentelemetry-instrumentation-sagemaker, opentelemetry-instrumentation-requests, opentelemetry-instrumentation-replicate, opentelemetry-instrumentation-redis, opentelemetry-instrumentation-qdrant, opentelemetry-instrumentation-pinecone, opentelemetry-instrumentation-openai-agents, opentelemetry-instrumentation-openai, opentelemetry-instrumentation-ollama, opentelemetry-instrumentation-mistralai, opentelemetry-instrumentation-milvus, opentelemetry-instrumentation-mcp, opentelemetry-instrumentation-marqo, opentelemetry-instrumentation-logging, opentelemetry-instrumentation-llamaindex, opentelemetry-instrumentation-langchain, opentelemetry-instrumentation-lancedb, opentelemetry-instrumentation-haystack, opentelemetry-instrumentation-groq, opentelemetry-instrumentation-google-generativeai, opentelemetry-instrumentation-crewai, opentelemetry-instrumentation-cohere, opentelemetry-instrumentation-chromadb, opentelemetry-instrumentation-bedrock, opentelemetry-instrumentation-anthropic, opentelemetry-instrumentation-alephalpha, opentelemetry-instrumentation-agno, opentelemetry-exporter-otlp-proto-http, opentelemetry-exporter-otlp-proto-grpc, langchain-openai, traceloop-sdk, literalai, chainlit
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 2.0.1
#     Uninstalling wrapt-2.0.1:
#       Successfully uninstalled wrapt-2.0.1
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.37.0
#     Uninstalling opentelemetry-proto-1.37.0:
#       Successfully uninstalled opentelemetry-proto-1.37.0
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-common
#     Found existing installation: opentelemetry-exporter-otlp-proto-common 1.37.0
#     Uninstalling opentelemetry-exporter-otlp-proto-common-1.37.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-common-1.37.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.37.0
#     Uninstalling opentelemetry-api-1.37.0:
#       Successfully uninstalled opentelemetry-api-1.37.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.58b0
#     Uninstalling opentelemetry-semantic-conventions-0.58b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.58b0
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.37.0
#     Uninstalling opentelemetry-sdk-1.37.0:
#       Successfully uninstalled opentelemetry-sdk-1.37.0
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.0.7
#     Uninstalling langchain-core-1.0.7:
#       Successfully uninstalled langchain-core-1.0.7
#   Attempting uninstall: opentelemetry-exporter-otlp-proto-http
#     Found existing installation: opentelemetry-exporter-otlp-proto-http 1.37.0
#     Uninstalling opentelemetry-exporter-otlp-proto-http-1.37.0:
#       Successfully uninstalled opentelemetry-exporter-otlp-proto-http-1.37.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.19.0 requires opentelemetry-api<=1.37.0,>=1.37.0, but you have opentelemetry-api 1.38.0 which is incompatible.
# google-adk 1.19.0 requires opentelemetry-sdk<=1.37.0,>=1.37.0, but you have opentelemetry-sdk 1.38.0 which is incompatible.
# Successfully installed anthropic-0.75.0 asyncer-0.0.10 bidict-0.23.1 chainlit-2.9.2 chevron-0.14.0 colorama-0.4.6 cuid-0.4 dataclasses-json-0.6.7 deprecated-1.3.1 filetype-1.2.0 inflection-0.5.1 langchain-core-1.1.0 langchain-openai-1.1.0 lazify-0.4.0 literalai-0.1.201 marshmallow-3.26.1 mypy-extensions-1.1.0 opentelemetry-api-1.38.0 opentelemetry-exporter-otlp-proto-common-1.38.0 opentelemetry-exporter-otlp-proto-grpc-1.38.0 opentelemetry-exporter-otlp-proto-http-1.38.0 opentelemetry-instrumentation-0.59b0 opentelemetry-instrumentation-agno-0.49.2 opentelemetry-instrumentation-alephalpha-0.49.2 opentelemetry-instrumentation-anthropic-0.49.2 opentelemetry-instrumentation-bedrock-0.49.2 opentelemetry-instrumentation-chromadb-0.49.2 opentelemetry-instrumentation-cohere-0.49.2 opentelemetry-instrumentation-crewai-0.49.2 opentelemetry-instrumentation-google-generativeai-0.49.2 opentelemetry-instrumentation-groq-0.49.2 opentelemetry-instrumentation-haystack-0.49.2 opentelemetry-instrumentation-lancedb-0.49.2 opentelemetry-instrumentation-langchain-0.49.2 opentelemetry-instrumentation-llamaindex-0.49.2 opentelemetry-instrumentation-logging-0.59b0 opentelemetry-instrumentation-marqo-0.49.2 opentelemetry-instrumentation-mcp-0.49.2 opentelemetry-instrumentation-milvus-0.49.2 opentelemetry-instrumentation-mistralai-0.49.2 opentelemetry-instrumentation-ollama-0.49.2 opentelemetry-instrumentation-openai-0.49.2 opentelemetry-instrumentation-openai-agents-0.49.2 opentelemetry-instrumentation-pinecone-0.49.2 opentelemetry-instrumentation-qdrant-0.49.2 opentelemetry-instrumentation-redis-0.59b0 opentelemetry-instrumentation-replicate-0.49.2 opentelemetry-instrumentation-requests-0.59b0 opentelemetry-instrumentation-sagemaker-0.49.2 opentelemetry-instrumentation-sqlalchemy-0.59b0 opentelemetry-instrumentation-threading-0.59b0 opentelemetry-instrumentation-together-0.49.2 opentelemetry-instrumentation-transformers-0.49.2 opentelemetry-instrumentation-urllib3-0.59b0 opentelemetry-instrumentation-vertexai-0.49.2 opentelemetry-instrumentation-watsonx-0.49.2 opentelemetry-instrumentation-weaviate-0.49.2 opentelemetry-instrumentation-writer-0.49.2 opentelemetry-proto-1.38.0 opentelemetry-sdk-1.38.0 opentelemetry-semantic-conventions-0.59b0 opentelemetry-semantic-conventions-ai-0.4.13 opentelemetry-util-http-0.59b0 python-engineio-4.12.3 python-socketio-5.15.0 simple-websocket-1.1.0 syncer-2.0.3 tomli-2.3.0 traceloop-sdk-0.49.2 typing-inspect-0.9.0 watchfiles-0.24.0 wrapt-1.17.3 wsproto-1.3.2

# %%
# !mkdir /content/rag_chatbot
# %cd /content/rag_chatbot
# Out:
# /content/rag_chatbot

# %%
# %%writefile .env
# OPENROUTER_API_KEY=
# OPENROUTER_BASE_URL=https://openrouter.ai/api/v1
# Out:
# Overwriting .env

# %% [markdown]
# ## Breaking Down the Code

# %%
# %%writefile chatbot.py
###############
# Initial setup
###############
from langchain_core.messages import HumanMessage, AIMessageChunk
from langchain_core.runnables.config import RunnableConfig
from langchain_openai import ChatOpenAI

from langgraph.checkpoint.memory import MemorySaver
from langgraph.graph import START, MessagesState, StateGraph
import chainlit as cl
import os
from dotenv import load_dotenv

import logging
logging.basicConfig(
    filename='app.log',
    level=logging.INFO,  # Log messages of INFO severity and above
    format='%(asctime)s - %(levelname)s - %(message)s' # Optional: format the log messages
)
logging.warning("Saving!")

load_dotenv()  # Load environment variables from a .env file

openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

####################
# Defining the Graph
####################
logging.warning("Defining the Graph!")
workflow = StateGraph(state_schema=MessagesState)

model = ChatOpenAI(
    #model='google/gemini-2.5-flash-lite',
    model='google/gemini-2.0-flash-exp:free',
    #model='google/gemma-3n-e4b-it:free',
    base_url=os.getenv('OPENROUTER_BASE_URL', 'https://openrouter.ai/api/v1'),
    api_key=openrouter_api_key,
    temperature=0,  # Set for deterministic, less creative responses
)

def call_model(state: MessagesState):
    """Invokes the model with the current state and returns the new message."""
    response = model.invoke(state['messages'])
    return {'messages': response}  # Update the state with the model's response

workflow.add_node('model', call_model)  # Add the model-calling function as a node
workflow.add_edge(START, 'model')  # Set the 'model' node as the entry point

######################
# Compliling the Graph
######################
logging.warning("Compliling the Graph!")
memory = MemorySaver()  # Initialize in-memory storage for conversation history

# Compile the graph into a runnable, adding the memory checkpointer
app = workflow.compile(checkpointer=memory)

##############################
# Integrating with Chainlit UI
##############################
logging.warning("Integrating with Chainlit UI!")
@cl.on_message
async def main(message: cl.Message):
    """Process incoming user messages and stream back the AI's response."""
    answer = cl.Message(content='...')  # Create an empty message to stream the response into
    await answer.send()

    # Configure the runnable to associate the conversation with the user's session
    config: RunnableConfig = {'configurable': {'thread_id': cl.context.session.thread_id}}

    # Stream the graph's output
    for msg, _ in app.stream(
        {'messages': [HumanMessage(content=message.content)]},  # Pass the user's message
        config,
        stream_mode='messages',  # Stream individual message chunks
    ):
        # Check if the current streamed item is an AI message chunk
        if isinstance(msg, AIMessageChunk):
            answer.content += msg.content  # type: ignore # Append the content chunk
            await answer.update()  # Update the UI with the appended content
# Out:
# Overwriting chatbot.py

# %% [markdown]
# ## Running and Testing Your Chatbot

# %%
#!chainlit run chatbot.py
# !while true; do nohup chainlit run chatbot.py -w >/dev/null 2>&1; sleep 5; done >/dev/null 2>&1 &

# %% [markdown]
# ### Colab

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://8000-m-s-3tmib24wemb5m-c.us-west1-1.prod.colab.dev

# %% [markdown]
# ### localtunnel

# %%
# !npm install -g localtunnel
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙
# changed 22 packages in 3s
# ⠙
# ⠙3 packages are looking for funding
# ⠙  run `npm fund` for details
# ⠙

# %%
# password: https://loca.lt/mytunnelpassword
# !lt --port 8000 & echo "password " & curl https://loca.lt/mytunnelpassword
# Out:
# password
# 104.196.233.114your url is: https://hot-parrots-kiss.loca.lt
